# %% [markdown]
# # ETL Project
# ---

# %% [markdown]
# ## Extract
#
# U.S. border-crossing data was extracted from the Bureau of Transportation Statistics (BTS) Border Crossing API (https://data.transportation.gov/Research-and-Statistics/Border-Crossing-Entry-Data/keg4-3bc2). Seeing as this data is found in the Socrata Public Data API, instead of extracting border-crossing data via JSON, the sodapy library was used.

# %%
# Dependencies
import pandas as pd
from sodapy import Socrata
import datetime as dt
from datetime import datetime

# %%
# Activate the Socrata Public Data API, specifically transportation data
client = Socrata("data.transportation.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.transportation.gov,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# Create conditions to ensure most rows will be used in final database
test_conditions = "date >= '2008-01-01' and value > 0 and (measure = 'Personal Vehicles' or \
                   measure = 'Personal Vehicles Passengers' or measure = 'Bus Passengers' or \
                   measure = 'Train Passengers') "

conditions = "date >= '2009-01-01' and value > 0"

# %%
# Request Border Entry data from specified API including additional conditions
results = client.get("keg4-3bc2", limit = 23000,  border = 'US-Canada Border', where = test_conditions)

# %%
# Create a Pandas Dataframe
results_df = pd.DataFrame.from_records(results)

# %%
# Preview the Dataframe
results_df = results_df.sort_values(by=['date'])

# %%
# Create a copy of the dataframe to manipulate the columns
clean_df = results_df.copy()
# Remove border and port code columns
clean_df = clean_df[['date','measure','port_name','state','value']]
# Change data type for date column
clean_df['date'] = pd.to_datetime(clean_df['date'])
# Set date as index
clean_df = clean_df.set_index('date')

# %%
clean_df
# Out:
#                       measure                   port_name         state  \
# date
# 2008-01-01  Personal Vehicles                    Oroville    Washington
# 2008-01-01     Bus Passengers                    Eastport         Idaho
# 2008-01-01  Personal Vehicles                   Limestone         Maine
# 2008-01-01     Bus Passengers                      Calais         Maine
# 2008-01-01     Bus Passengers              Metaline Falls    Washington
# 2008-01-01  Personal Vehicles                     Laurier    Washington
# 2008-01-01  Personal Vehicles                      Sarles  North Dakota
# 2008-01-01     Bus Passengers                    Porthill         Idaho
# 2008-01-01     Bus Passengers                     Laurier    Washington
# 2008-01-01  Personal Vehicles                    Porthill         Idaho
# 2008-01-01     Bus Passengers                  Ogdensburg      New York
# 2008-01-01  Personal Vehicles               Beecher Falls       Vermont
# 2008-01-01   Train Passengers                     Detroit      Michigan
# 2008-01-01  Personal Vehicles                   Northgate  North Dakota
# 2008-01-01  Personal Vehicles                      Hannah  North Dakota
# 2008-01-01     Bus Passengers                    Frontier    Washington
# 2008-01-01  Personal Vehicles                      Opheim       Montana
# 2008-01-01  Personal Vehicles                   Roosville       Montana
# 2008-01-01  Personal Vehicles     Highgate Springs-Alburg       Vermont
# 2008-01-01  Personal Vehicles                      Blaine    Washington
# 2008-01-01  Personal Vehicles                    Dunseith  North Dakota
# 2008-01-01  Personal Vehicles                     Carbury  North Dakota
# 2008-01-01     Bus Passengers                   Anacortes    Washington
# 2008-01-01  Personal Vehicles                       Alcan        Alaska
# 2008-01-01  Personal Vehicles                  Del Bonita       Montana
# 2008-01-01  Personal Vehicles      Champlain-Rouses Point      New York
# 2008-01-01     Bus Passengers                     Pembina  North Dakota
# 2008-01-01  Personal Vehicles                     Warroad     Minnesota
# 2008-01-01  Personal Vehicles               Grand Portage     Minnesota
# 2008-01-01   Train Passengers                    Baudette     Minnesota
# ...                       ...                         ...           ...
# 2019-06-01  Personal Vehicles  International Falls-Ranier     Minnesota
# 2019-06-01     Bus Passengers  International Falls-Ranier     Minnesota
# 2019-06-01  Personal Vehicles               Grand Portage     Minnesota
# 2019-06-01     Bus Passengers               Grand Portage     Minnesota
# 2019-06-01  Personal Vehicles                    Baudette     Minnesota
# 2019-06-01     Bus Passengers                    Baudette     Minnesota
# 2019-06-01   Train Passengers          Sault Sainte Marie      Michigan
# 2019-06-01  Personal Vehicles                      Opheim       Montana
# 2019-06-01     Bus Passengers          Sault Sainte Marie      Michigan
# 2019-06-01     Bus Passengers                      Piegan       Montana
# 2019-06-01     Bus Passengers                     Raymond       Montana
# 2019-06-01  Personal Vehicles                  Derby Line       Vermont
# 2019-06-01  Personal Vehicles               Beecher Falls       Vermont
# 2019-06-01  Personal Vehicles                      Antler  North Dakota
# 2019-06-01  Personal Vehicles                     Ambrose  North Dakota
# 2019-06-01  Personal Vehicles                Willow Creek       Montana
# 2019-06-01  Personal Vehicles                   Wildhorse       Montana
# 2019-06-01     Bus Passengers                   Wildhorse       Montana
# 2019-06-01  Personal Vehicles                    Whitlash       Montana
# 2019-06-01  Personal Vehicles                      Turner       Montana
# 2019-06-01     Bus Passengers                      Turner       Montana
# 2019-06-01   Train Passengers                  Sweetgrass       Montana
# 2019-06-01  Personal Vehicles                  Sweetgrass       Montana
# 2019-06-01     Bus Passengers                  Sweetgrass       Montana
# 2019-06-01  Personal Vehicles                      Scobey       Montana
# 2019-06-01  Personal Vehicles                   Roosville       Montana
# 2019-06-01     Bus Passengers                   Roosville       Montana
# 2019-06-01  Personal Vehicles                     Raymond       Montana
# 2019-06-01  Personal Vehicles                      Piegan       Montana
# 2019-06-01     Bus Passengers                       Alcan        Alaska
#
#              value
# date
# 2008-01-01   14091
# 2008-01-01     227
# 2008-01-01    3030
# 2008-01-01     405
# 2008-01-01     183
# 2008-01-01    2870
# 2008-01-01     263
# 2008-01-01     457
# 2008-01-01     134
# 2008-01-01    9917
# 2008-01-01     293
# 2008-01-01    4315
# 2008-01-01     828
# 2008-01-01    1086
# 2008-01-01     167
# 2008-01-01     526
# 2008-01-01     263
# 2008-01-01    5094
# 2008-01-01   29939
# 2008-01-01  193559
# 2008-01-01    3225
# 2008-01-01     796
# 2008-01-01      17
# 2008-01-01     749
# 2008-01-01     978
# 2008-01-01   58683
# 2008-01-01    3275
# 2008-01-01    7383
# 2008-01-01   14470
# 2008-01-01     224
# ...            ...
# 2019-06-01   41703
# 2019-06-01     792
# 2019-06-01   22204
# 2019-06-01     772
# 2019-06-01   16330
# 2019-06-01     378
# 2019-06-01      58
# 2019-06-01     371
# 2019-06-01    1124
# 2019-06-01     579
# 2019-06-01      36
# 2019-06-01   49419
# 2019-06-01    7482
# 2019-06-01     574
# 2019-06-01     105
# 2019-06-01     215
# 2019-06-01    1462
# 2019-06-01      50
# 2019-06-01      36
# 2019-06-01     760
# 2019-06-01      25
# 2019-06-01     195
# 2019-06-01   16154
# 2019-06-01     337
# 2019-06-01     544
# 2019-06-01   16818
# 2019-06-01     195
# 2019-06-01    2431
# 2019-06-01   13899
# 2019-06-01    1047
#
# [21454 rows x 4 columns]

# %%
clean_df
# Out:
#             date            measure                   port_name         state  \
# 0     2008-01-01  Personal Vehicles                    Oroville    Washington
# 1     2008-01-01  Personal Vehicles                   Nighthawk    Washington
# 2     2008-01-01  Personal Vehicles                      Turner       Montana
# 3     2008-01-01     Bus Passengers      Champlain-Rouses Point      New York
# 4     2008-01-01     Bus Passengers          Sault Sainte Marie      Michigan
# 5     2008-01-01  Personal Vehicles                     Ambrose  North Dakota
# 6     2008-01-01     Bus Passengers                     Massena      New York
# 7     2008-01-01   Train Passengers                   Vanceboro         Maine
# 8     2008-01-01   Train Passengers                    Eastport         Idaho
# 9     2008-01-01     Bus Passengers                  Sweetgrass       Montana
# 10    2008-01-01     Bus Passengers                  Derby Line       Vermont
# 11    2008-01-01   Train Passengers                      Portal  North Dakota
# 12    2008-01-01     Bus Passengers                Dalton Cache        Alaska
# 13    2008-01-01   Train Passengers                      Blaine    Washington
# 14    2008-01-01   Train Passengers  International Falls-Ranier     Minnesota
# 15    2008-01-01  Personal Vehicles                Dalton Cache        Alaska
# 16    2008-01-01  Personal Vehicles                   Lancaster     Minnesota
# 17    2008-01-01     Bus Passengers                       Alcan        Alaska
# 18    2008-01-01  Personal Vehicles              Fort Fairfield         Maine
# 19    2008-01-01     Bus Passengers                     Detroit      Michigan
# 20    2008-01-01     Bus Passengers               Point Roberts    Washington
# 21    2008-01-01     Bus Passengers                     Houlton         Maine
# 22    2008-01-01  Personal Vehicles                      Lynden    Washington
# 23    2008-01-01     Bus Passengers                   Roosville       Montana
# 24    2008-01-01     Bus Passengers                    Eastport         Maine
# 25    2008-01-01  Personal Vehicles                       Ferry    Washington
# 26    2008-01-01   Train Passengers                      Calais         Maine
# 27    2008-01-01  Personal Vehicles                      Norton       Vermont
# 28    2008-01-01  Personal Vehicles                      Morgan       Montana
# 29    2008-01-01   Train Passengers                     Pembina  North Dakota
# ...          ...                ...                         ...           ...
# 21424 2019-06-01  Personal Vehicles                    Sherwood  North Dakota
# 21425 2019-06-01  Personal Vehicles                      Sarles  North Dakota
# 21426 2019-06-01     Bus Passengers                      Sarles  North Dakota
# 21427 2019-06-01   Train Passengers                      Portal  North Dakota
# 21428 2019-06-01  Personal Vehicles                      Portal  North Dakota
# 21429 2019-06-01     Bus Passengers                      Portal  North Dakota
# 21430 2019-06-01   Train Passengers                     Pembina  North Dakota
# 21431 2019-06-01  Personal Vehicles                     Pembina  North Dakota
# 21432 2019-06-01     Bus Passengers                     Pembina  North Dakota
# 21433 2019-06-01   Train Passengers                   Northgate  North Dakota
# 21434 2019-06-01  Personal Vehicles                   Northgate  North Dakota
# 21435 2019-06-01  Personal Vehicles                      Noonan  North Dakota
# 21436 2019-06-01  Personal Vehicles                       Neche  North Dakota
# 21437 2019-06-01  Personal Vehicles                       Maida  North Dakota
# 21438 2019-06-01  Personal Vehicles                    Hansboro  North Dakota
# 21439 2019-06-01  Personal Vehicles                      Hannah  North Dakota
# 21440 2019-06-01  Personal Vehicles                     Fortuna  North Dakota
# 21441 2019-06-01  Personal Vehicles                    Dunseith  North Dakota
# 21442 2019-06-01     Bus Passengers                    Dunseith  North Dakota
# 21443 2019-06-01  Personal Vehicles                     Carbury  North Dakota
# 21444 2019-06-01     Bus Passengers                     Carbury  North Dakota
# 21445 2019-06-01   Train Passengers                     Skagway        Alaska
# 21446 2019-06-01  Personal Vehicles                     Skagway        Alaska
# 21447 2019-06-01     Bus Passengers                     Skagway        Alaska
# 21448 2019-06-01  Personal Vehicles                   Ketchikan        Alaska
# 21449 2019-06-01     Bus Passengers                   Ketchikan        Alaska
# 21450 2019-06-01  Personal Vehicles                Dalton Cache        Alaska
# 21451 2019-06-01     Bus Passengers                Dalton Cache        Alaska
# 21452 2019-06-01  Personal Vehicles                       Alcan        Alaska
# 21453 2019-06-01     Bus Passengers                       Alcan        Alaska
#
#        value
# 0      14091
# 1        323
# 2        221
# 3      14691
# 4      20912
# 5         93
# 6       2473
# 7         55
# 8        172
# 9        184
# 10      3904
# 11       627
# 12        95
# 13      2014
# 14       674
# 15       448
# 16      3401
# 17        22
# 18     12449
# 19     83524
# 20      1487
# 21       198
# 22     38796
# 23       547
# 24        70
# 25       541
# 26        22
# 27      5475
# 28       319
# 29       224
# ...      ...
# 21424   1303
# 21425    325
# 21426     28
# 21427    444
# 21428   6947
# 21429    244
# 21430    248
# 21431  24210
# 21432   1268
# 21433     45
# 21434   1122
# 21435   2320
# 21436   3489
# 21437    725
# 21438    518
# 21439     84
# 21440   1434
# 21441   6161
# 21442    220
# 21443    998
# 21444     30
# 21445  27454
# 21446  10886
# 21447  48767
# 21448    458
# 21449     60
# 21450   2755
# 21451    156
# 21452  10850
# 21453   1047
#
# [21454 rows x 5 columns]

# %%
results_df['measure'].value_counts()
# Out:
# Personal Vehicles    11568
# Bus Passengers        6542
# Train Passengers      3344
# Name: measure, dtype: int64
